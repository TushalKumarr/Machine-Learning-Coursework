# %% [markdown]
# # Machine Learning Lab 01 — Python Basics
# ---

# %% [markdown]
# ## Activity 01: Personal Info Card Generator

# %%
name = "Tushal Kumar"
cms_id = "023-24-0487"
email = "tushalkumar.bscsf24kdk@iba-suk.edu.pk"
department = "Computer Science"
university = "Sukkur IBA University"
campus = "Kandhkot Campus"
semester = "V"

# %%
print("========== PERSONAL INFO ==========")
print(f"Name       : {name}")
print(f"CMS ID : {cms_id}")
print(f"Email        : {email}")
print(f"Department : {department}")
print(f"University : {university}")
print(f"Campus : {campus}")
print(f"Semester : {semester}")
print("===================================")
# Out:
# ========== PERSONAL INFO ==========
# Name       : Tushal Kumar
# CMS ID : 023-24-0487
# Email        : tushalkumar.bscsf24kdk@iba-suk.edu.pk
# Department : Computer Science
# University : Sukkur IBA University
# Campus : Kandhkot Campus
# Semester : V
# ...

# %% [markdown]
# ## Activity 02: String Slicing and Formatting

# %%
sentence = "   Python Programming is Amazing   "
print(f"Printing Sentence into Unorganized Form: {sentence}")

# cleaning:
sentence = sentence.strip()
print(f"Printing Sentence into Organized Form: {sentence}")
# Out:
# Printing Sentence into Unorganized Form:    Python Programming is Amazing
# Printing Sentence into Organized Form: Python Programming is Amazing

# %%
# Slicing: we have to fetch these characters only: "Pyt"
sentence[0:3]
# Out:
# 'Pyt'

# %% [markdown]
# ## Exercise 01: Basic Math & Variable Swapping

# %%
a, b = 15, 40

# swap values:
a, b = b, a

# calculations:
sum_result = a + b
product = a * b
division = a / b

# Display results
print(f"a = {a}")
print(f"b = {b}")
print(f"Sum = {sum_result}")
print(f"Product = {product}")
print(f"Division = {division:.2f}")
# Out:
# a = 40
# b = 15
# Sum = 55
# Product = 600
# Division = 2.67

# %% [markdown]
# ## Exercise 2: Username & Email Generator

# %%
# store the name:
username = "Tushal Kumar"

# convert into lower case:
username = username.lower()

# replace space with underscore:
username = username.replace(" ", "_")

# creating domain email:
domain = "@iba-suk.edu.pk"
email = username + domain # string concatenation using +

# printing
print(f"Username: {username}")
print(f"Email: {email}")
# Out:
# Username: tushal_kumar
# Email: tushal_kumar@iba-suk.edu.pk

# %% [markdown]
# ## Exercise 3: String Reversal & Palindrome Checker
# ---
#
# ### What is a palindrome?
#
# #### A palindrome is something that reads the same forward and backward.
#
# #### Example: madam = madam

# %%
text = "Nurses Run"

# removing space and converting into lower case:
cleaned = text.replace(" ", "").lower()

# reverse the string:
reversed_text = cleaned[::-1]

print(reversed_text)
# Out:
# nursesrun
